# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("dataset_final.csv", index_col=0)
df.head()
# Out:
#    Ano_sem  ear_max_subsistema  ear_verif_subsistema_mwmes  \
# 0  2001_26             49967.0                12325.000000
# 1  2001_27             49967.0                11979.428571
# 2  2001_28             49967.0                11546.000000
# 3  2001_29             49967.0                11191.571429
# 4  2001_30             49967.0                10770.000000
#
#    ear_verif_subsistema_percentual  ena_bruta_regiao_mwmed  \
# 0                        24.665715             2249.714286
# 1                        23.975714             2106.142857
# 2                        23.107143             1930.857143
# 3                        22.397143             2048.000000
# 4                        21.555714             1889.285714
#
#    ena_bruta_regiao_percentualmlt  ena_armazenavel_regiao_mwmed  \
# 0                       50.405714                   2249.714286
# 1                       55.701429                   2106.142857
# ...

# %%
df.describe()
# Out:
#        ear_max_subsistema  ear_verif_subsistema_mwmes  \
# count         1203.000000                 1203.000000
# mean         51443.947356                27272.798523
# std            681.161439                13056.824635
# min          49967.000000                 2279.142857
# 25%          51602.070312                16890.111111
# 50%          51766.000000                27435.852958
# 75%          51809.000000                38067.369420
# max          52624.082031                51399.571429
#
#        ear_verif_subsistema_percentual  ena_bruta_regiao_mwmed  \
# count                      1203.000000             1203.000000
# mean                         53.012662             5473.011150
# std                          25.406819             4707.516864
# min                           4.401429              689.714286
# 25%                          32.757143             2139.257629
# 50%                          53.200000             3562.062430
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.NORDESTE.describe()
# Out:
# count    1203.000000
# mean      164.513608
# std       189.783171
# min         4.000000
# 25%        23.555000
# 50%        80.480000
# 75%       222.700000
# max       822.830000
# Name: NORDESTE, dtype: float64

# %%
sns.histplot(df.NORDESTE)
# Out:
# <Axes: xlabel='NORDESTE', ylabel='Count'>
